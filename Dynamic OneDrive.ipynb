# %%
import pandas as pd
import os
from openpyxl import load_workbook

# Dynamically get the local user's OneDrive directory
base_path = os.path.expanduser(r"~\OneDrive - Etex Group")

file_path = os.path.join(base_path, r"Desktop\Etex AU - Finance - Finance\06. Revenue & Pricing\Etex\01. Revenue\08. Margin\2025\BW reports\Raw Data.xlsx")
df = pd.read_excel(file_path)

# %%
df.head()
# Out:
#   Fiscal year/period Customer              Customer Name Material  \
# 0        K4/003.2025     1106  ETEX AUSTRALIA MATRAVILLE   298029
# 1        K4/003.2025     1106  ETEX AUSTRALIA MATRAVILLE   298041
# 2        K4/003.2025     1106  ETEX AUSTRALIA MATRAVILLE   298054
# 3        K4/003.2025     1106  ETEX AUSTRALIA MATRAVILLE   298067
# 4        K4/003.2025     1106  ETEX AUSTRALIA MATRAVILLE   298089
#
#                 Material Description Region Plant  Actual Cost Of Goods Sold  \
# 0  10 x 1200 x 3600 Soundshield (60)    NSW  5502                        NaN
# 1  10 x 1200 x 6000 Soundshield (40)    NSW  5502                        NaN
# 2  10 x 1350 x 3600 Soundshield (60)    NSW  5502                        NaN
# 3  10 x 1350 x 6000 Soundshield (40)    NSW  5502                        NaN
# 4  13 x 1200 x 3600 Multishield (50)    NSW  5502                        NaN
#
#    Quantity  Gross Sales (Invoice)  ...  Transport to Customers  \
# ...
